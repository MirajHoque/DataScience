# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
from googletrans import Translator

# %%
from textblob import TextBlob

# %%
text =" খুব ভোরে ঘুম থেকে উঠার অভ্যাস কখনো আমার হবে না। বিশ্ববিদ্যালয় যায়গাটাতে সবসময় কেন দেরি করে যেতে হবে আমার? রোজ রোজ একাজ করা উচিত না। বিশ্ববিদ্যালয় যাওয়ার পর প্রিয়জনকে দেখলে ভীষণ ভালো লাগে। পড়তে ভালো লাগে না। তাকে না দেখলে সময় ভালো কাটেনা। মনটা কেমন  কেমন করে। তুমি বেঁচে থাকবে হয়ে আমার প্রিয়তমা। "
a='। '
b='.'

newText=text.replace(a,b)

# %%
n=','
finalText=newText.replace(b,n)
print(finalText)
#print(finalText[0])
# Out:
#  খুব ভোরে ঘুম থেকে উঠার অভ্যাস কখনো আমার হবে না,বিশ্ববিদ্যালয় যায়গাটাতে সবসময় কেন দেরি করে যেতে হবে আমার? রোজ রোজ একাজ করা উচিত না,বিশ্ববিদ্যালয় যাওয়ার পর প্রিয়জনকে দেখলে ভীষণ ভালো লাগে,পড়তে ভালো লাগে না,তাকে না দেখলে সময় ভালো কাটেনা,মনটা কেমন  কেমন করে,তুমি বেঁচে থাকবে হয়ে আমার প্রিয়তমা,

# %%
tokenized_sents=[sent_tokenize(i) for i in finalText]
for i in tokenized_sents:
    print(i)
# Out:
# []
# ['খ']
# ['ু']
# ['ব']
# []
# ['ভ']
# ['ো']
# ['র']
# ['ে']
# []
# ['ঘ']
# ['ু']
# ['ম']
# []
# ['থ']
# ['ে']
# ['ক']
# ['ে']
# []
# ['উ']
# ['ঠ']
# ['া']
# ['র']
# []
# ['অ']
# ['ভ']
# ['্']
# ['য']
# ['া']
# ['স']
# []
# ['ক']
# ['খ']
# ['ন']
# ['ো']
# []
# ['আ']
# ['ম']
# ['া']
# ['র']
# []
# ['হ']
# ['ব']
# ['ে']
# []
# ['ন']
# ['া']
# [',']
# ['ব']
# ['ি']
# ['শ']
# ['্']
# ['ব']
# ['ব']
# ['ি']
# ['দ']
# ['্']
# ['য']
# ['া']
# ['ল']
# ['য']
# ['়']
# []
# ['য']
# ['া']
# ['য়']
# ['গ']
# ['া']
# ['ট']
# ['া']
# ['ত']
# ['ে']
# []
# ['স']
# ['ব']
# ['স']
# ['ম']
# ['য়']
# []
# ['ক']
# ['ে']
# ['ন']
# []
# ['দ']
# ['ে']
# ['র']
# ['ি']
# []
# ['ক']
# ['র']
# ['ে']
# []
# ['য']
# ['ে']
# ['ত']
# ['ে']
# []
# ['হ']
# ['ব']
# ['ে']
# []
# ['আ']
# ['ম']
# ['া']
# ['র']
# ['?']
# []
# ['র']
# ['ো']
# ['জ']
# []
# ['র']
# ['ো']
# ['জ']
# []
# ['এ']
# ['ক']
# ['া']
# ['জ']
# []
# ['ক']
# ['র']
# ['া']
# []
# ['উ']
# ['চ']
# ['ি']
# ['ত']
# []
# ['ন']
# ['া']
# [',']
# ['ব']
# ['ি']
# ['শ']
# ['্']
# ['ব']
# ['ব']
# ['ি']
# ['দ']
# ['্']
# ['য']
# ['া']
# ['ল']
# ['য']
# ['়']
# []
# ['য']
# ['া']
# ['ও']
# ['য়']
# ['া']
# ['র']
# []
# ['প']
# ['র']
# []
# ['প']
# ['্']
# ['র']
# ['ি']
# ['য']
# ['়']
# ['জ']
# ['ন']
# ['ক']
# ['ে']
# []
# ['দ']
# ['ে']
# ['খ']
# ['ল']
# ['ে']
# []
# ['ভ']
# ['ী']
# ['ষ']
# ['ণ']
# []
# ['ভ']
# ['া']
# ['ল']
# ['ো']
# []
# ['ল']
# ['া']
# ['গ']
# ['ে']
# [',']
# ['প']
# ['ড়']
# ['ত']
# ['ে']
# []
# ['ভ']
# ['া']
# ['ল']
# ['ো']
# []
# ['ল']
# ['া']
# ['গ']
# ['ে']
# []
# ['ন']
# ['া']
# [',']
# ['ত']
# ['া']
# ['ক']
# ['ে']
# []
# ['ন']
# ['া']
# []
# ['দ']
# ['ে']
# ['খ']
# ['ল']
# ['ে']
# []
# ['স']
# ['ম']
# ['য়']
# []
# ['ভ']
# ['া']
# ['ল']
# ['ো']
# []
# ['ক']
# ['া']
# ['ট']
# ['ে']
# ['ন']
# ['া']
# [',']
# ['ম']
# ['ন']
# ['ট']
# ['া']
# []
# ['ক']
# ['ে']
# ['ম']
# ['ন']
# []
# []
# ['ক']
# ['ে']
# ['ম']
# ['ন']
# []
# ['ক']
# ['র']
# ['ে']
# [',']
# ['ত']
# ['ু']
# ['ম']
# ['ি']
# []
# ['ব']
# ['ে']
# ['ঁ']
# ['চ']
# ['ে']
# []
# ['থ']
# ['া']
# ['ক']
# ['ব']
# ['ে']
# []
# ['হ']
# ['য়']
# ['ে']
# []
# ['আ']
# ['ম']
# ['া']
# ['র']
# []
# ['প']
# ['্']
# ['র']
# ['ি']
# ['য়']
# ['ত']
# ['ম']
# ['া']
# [',']
